# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (1.21.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.3.4-cp39-cp39-win_amd64.whl (10.2 MB)
# Requirement already satisfied: pytz>=2017.3 in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.3.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wordcloud
# Out:
#   File "C:\Users\hommet74\AppData\Local\Temp/ipykernel_25400/956646509.py", line 1
#     pip install wordcloud
#         ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from scipy.stats import norm,mode
import re
from wordcloud import WordCloud
plt.rcParms['font.sans-serif']=['SimHei']
plt.rcParms['axes.unicode_minus']=False
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25640/3048405309.py in <module>
#       5 from scipy.stats import norm,mode
#       6 import re
# ----> 7 from wordcloud import WordCloud
#       8 plt.rcParms['font.sans-serif']=['SimHei']
#       9 plt.rcParms['axes.unicode_minus']=False
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.1.tar.gz (220 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.6.1 in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from wordcloud) (1.21.2)
# Requirement already satisfied: pillow in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from wordcloud) (8.3.2)
# Requirement already satisfied: matplotlib in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: six in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Using legacy 'setup.py install' for wordcloud, since package 'wheel' is not installed.
# Installing collected packages: wordcloud
#     Running setup.py install for wordcloud: started
#     Running setup.py install for wordcloud: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\hommet74\AppData\Local\Programs\Python\Python39\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\hommet74\\AppData\\Local\\Temp\\pip-install-o6839h70\\wordcloud_a1e589ff2fc44500af388522a0743be1\\setup.py'"'"'; __file__='"'"'C:\\Users\\hommet74\\AppData\\Local\\Temp\\pip-install-o6839h70\\wordcloud_a1e589ff2fc44500af388522a0743be1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\hommet74\AppData\Local\Temp\pip-record-ezfvgilm\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\hommet74\AppData\Local\Programs\Python\Python39\Include\wordcloud'
#          cwd: C:\Users\hommet74\AppData\Local\Temp\pip-install-o6839h70\wordcloud_a1e589ff2fc44500af388522a0743be1\
#     Complete output (20 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\color_from_image.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\tokenization.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\wordcloud.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\_version.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\__init__.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\__main__.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\stopwords -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-3.9\wordcloud
#     UPDATING build\lib.win-amd64-3.9\wordcloud/_version.py
#     set build\lib.win-amd64-3.9\wordcloud/_version.py to '1.8.1'
#     running build_ext
#     building 'wordcloud.query_integral_image' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\hommet74\AppData\Local\Programs\Python\Python39\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\hommet74\\AppData\\Local\\Temp\\pip-install-o6839h70\\wordcloud_a1e589ff2fc44500af388522a0743be1\\setup.py'"'"'; __file__='"'"'C:\\Users\\hommet74\\AppData\\Local\\Temp\\pip-install-o6839h70\\wordcloud_a1e589ff2fc44500af388522a0743be1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\hommet74\AppData\Local\Temp\pip-record-ezfvgilm\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\hommet74\AppData\Local\Programs\Python\Python39\Include\wordcloud' Check the logs for full command output.

# %%
conda install -c conda-forge wordcloud
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25640/415980018.py in <module>
# ----> 1 get_ipython().run_line_magic('conda', 'install -c conda-forge wordcloud')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\magics\packaging.py in conda(self, line)
#      84         """
#      85         if not _is_conda_environment():
# ---> 86             raise ValueError("The python kernel does not appear to be a conda environment.  "
#      87                              "Please use ``%pip install`` instead.")
#      88
#
# ValueError: The python kernel does not appear to be a conda environment.  Please use ``%pip install`` instead.

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Using cached wordcloud-1.8.1.tar.gz (220 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.6.1 in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from wordcloud) (1.21.2)
# Requirement already satisfied: pillow in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from wordcloud) (8.3.2)
# Requirement already satisfied: matplotlib in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: six in c:\users\hommet74\appdata\local\programs\python\python39\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Using legacy 'setup.py install' for wordcloud, since package 'wheel' is not installed.
# Installing collected packages: wordcloud
#     Running setup.py install for wordcloud: started
#     Running setup.py install for wordcloud: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\hommet74\AppData\Local\Programs\Python\Python39\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\hommet74\\AppData\\Local\\Temp\\pip-install-r4rupt0o\\wordcloud_83caa7504131499db9bf199555ccd431\\setup.py'"'"'; __file__='"'"'C:\\Users\\hommet74\\AppData\\Local\\Temp\\pip-install-r4rupt0o\\wordcloud_83caa7504131499db9bf199555ccd431\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\hommet74\AppData\Local\Temp\pip-record-u8n47p5l\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\hommet74\AppData\Local\Programs\Python\Python39\Include\wordcloud'
#          cwd: C:\Users\hommet74\AppData\Local\Temp\pip-install-r4rupt0o\wordcloud_83caa7504131499db9bf199555ccd431\
#     Complete output (20 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\color_from_image.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\tokenization.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\wordcloud.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\_version.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\__init__.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\__main__.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\stopwords -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-3.9\wordcloud
#     UPDATING build\lib.win-amd64-3.9\wordcloud/_version.py
#     set build\lib.win-amd64-3.9\wordcloud/_version.py to '1.8.1'
#     running build_ext
#     building 'wordcloud.query_integral_image' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\hommet74\AppData\Local\Programs\Python\Python39\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\hommet74\\AppData\\Local\\Temp\\pip-install-r4rupt0o\\wordcloud_83caa7504131499db9bf199555ccd431\\setup.py'"'"'; __file__='"'"'C:\\Users\\hommet74\\AppData\\Local\\Temp\\pip-install-r4rupt0o\\wordcloud_83caa7504131499db9bf199555ccd431\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\hommet74\AppData\Local\Temp\pip-record-u8n47p5l\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\hommet74\AppData\Local\Programs\Python\Python39\Include\wordcloud' Check the logs for full command output.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from scipy.stats import norm,mode
import re
#from wordcloud import WordCloud
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('./boss.csv',header=None,names=['company','position','address','salary','requires','labels','tags'])

# %%
df.info
# Out:
# <bound method DataFrame.info of      company      position address    salary  requires labels  \
# 0       安存科技         数据分析师      长沙     9-14K    1-3年本科  计算机软件
# 1       名利天下         数据分析师      长沙      2-3K  经验不限学历不限  移动互联网
# 2       长沙沃邦         数据分析师      长沙     5-10K    经验不限大专   企业服务
# 3         谊品         数据分析师      长沙      3-8K    3-5年大专  其他服务业
# 4       众美健康         数据分析师      长沙    10-15K    经验不限本科  计算机软件
# ...      ...           ...     ...       ...       ...    ...
# 2532    今日头条         数据分析师      西安  6-8K·15薪    1-3年本科  移动互联网
# 2533     众科源  7k起急招运营数据分析师      西安     7-10K    经验不限本科   电子商务
# 2534    今日头条         数据分析师      西安  6-8K·15薪    1-3年本科  移动互联网
# 2535    今日头条         数据分析师      西安  4-6K·15薪    经验不限本科  移动互联网
# 2536    今日头条         数据分析师      西安  4-6K·15薪    经验不限本科  移动互联网
#
#                                     tags
# 0                数据挖掘,大数据,工业数据,模型产品,特征工程
# 1              数据挖掘,数据分析师,店铺运营管理,战略目标,策划
# 2                  SPSS,VBA,建模,数据分析师,统计学
# 3               Python,SQL,数据分析师,数据分析管理,
# 4             大数据,数据挖掘,数据仓库,商业数据分析,数据分析师
# ...                                  ...
# 2532     Tableau，数据挖掘，BI，行业技术发展，心理学等相关专业
# 2533              数学，统计学，运营数据分析，亚马逊，电商平台
# 2534  Tableau，数据挖掘，行业技术发展，心理学等相关专业，数据分析师
# 2535         数据挖掘，Python，数据分析师，业务数据，风险报告
# 2536         数据挖掘，Python，数据开发，数据分析师，业务数据
#
# [2537 rows x 7 columns]>

# %%
df.head
# Out:
# <bound method NDFrame.head of      company      position address    salary  requires labels  \
# 0       安存科技         数据分析师      长沙     9-14K    1-3年本科  计算机软件
# 1       名利天下         数据分析师      长沙      2-3K  经验不限学历不限  移动互联网
# 2       长沙沃邦         数据分析师      长沙     5-10K    经验不限大专   企业服务
# 3         谊品         数据分析师      长沙      3-8K    3-5年大专  其他服务业
# 4       众美健康         数据分析师      长沙    10-15K    经验不限本科  计算机软件
# ...      ...           ...     ...       ...       ...    ...
# 2532    今日头条         数据分析师      西安  6-8K·15薪    1-3年本科  移动互联网
# 2533     众科源  7k起急招运营数据分析师      西安     7-10K    经验不限本科   电子商务
# 2534    今日头条         数据分析师      西安  6-8K·15薪    1-3年本科  移动互联网
# 2535    今日头条         数据分析师      西安  4-6K·15薪    经验不限本科  移动互联网
# 2536    今日头条         数据分析师      西安  4-6K·15薪    经验不限本科  移动互联网
#
#                                     tags
# 0                数据挖掘,大数据,工业数据,模型产品,特征工程
# 1              数据挖掘,数据分析师,店铺运营管理,战略目标,策划
# 2                  SPSS,VBA,建模,数据分析师,统计学
# 3               Python,SQL,数据分析师,数据分析管理,
# 4             大数据,数据挖掘,数据仓库,商业数据分析,数据分析师
# ...                                  ...
# 2532     Tableau，数据挖掘，BI，行业技术发展，心理学等相关专业
# 2533              数学，统计学，运营数据分析，亚马逊，电商平台
# 2534  Tableau，数据挖掘，行业技术发展，心理学等相关专业，数据分析师
# 2535         数据挖掘，Python，数据分析师，业务数据，风险报告
# 2536         数据挖掘，Python，数据开发，数据分析师，业务数据
#
# [2537 rows x 7 columns]>

# %%
df.shape
# Out:
# (2537, 7)

# %%
df.duplicated().sum()
# Out:
# 11

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (2526, 7)

# %%
x=df['position'].str.contains('实习')
df=df[~x]

# %%
df
# Out:
#      company      position address    salary  requires labels  \
# 0       安存科技         数据分析师      长沙     9-14K    1-3年本科  计算机软件
# 1       名利天下         数据分析师      长沙      2-3K  经验不限学历不限  移动互联网
# 2       长沙沃邦         数据分析师      长沙     5-10K    经验不限大专   企业服务
# 3         谊品         数据分析师      长沙      3-8K    3-5年大专  其他服务业
# 4       众美健康         数据分析师      长沙    10-15K    经验不限本科  计算机软件
# ...      ...           ...     ...       ...       ...    ...
# 2532    今日头条         数据分析师      西安  6-8K·15薪    1-3年本科  移动互联网
# 2533     众科源  7k起急招运营数据分析师      西安     7-10K    经验不限本科   电子商务
# 2534    今日头条         数据分析师      西安  6-8K·15薪    1-3年本科  移动互联网
# 2535    今日头条         数据分析师      西安  4-6K·15薪    经验不限本科  移动互联网
# 2536    今日头条         数据分析师      西安  4-6K·15薪    经验不限本科  移动互联网
#
#                                     tags
# 0                数据挖掘,大数据,工业数据,模型产品,特征工程
# 1              数据挖掘,数据分析师,店铺运营管理,战略目标,策划
# 2                  SPSS,VBA,建模,数据分析师,统计学
# 3               Python,SQL,数据分析师,数据分析管理,
# 4             大数据,数据挖掘,数据仓库,商业数据分析,数据分析师
# ...                                  ...
# 2532     Tableau，数据挖掘，BI，行业技术发展，心理学等相关专业
# 2533              数学，统计学，运营数据分析，亚马逊，电商平台
# 2534  Tableau，数据挖掘，行业技术发展，心理学等相关专业，数据分析师
# 2535         数据挖掘，Python，数据分析师，业务数据，风险报告
# 2536         数据挖掘，Python，数据开发，数据分析师，业务数据
#
# [2472 rows x 7 columns]

# %%
df.address.unique()
# Out:
# array(['长沙', '成都', '郑州', '重庆', '南京', '武汉', '厦门', '杭州', '北京', '广州', '上海',
#        '深圳', '苏州', '天津', '西安'], dtype=object)

# %%
df.company.unique()
# Out:
# array(['安存科技', '名利天下', '长沙沃邦', ..., '垚海科技', '西安航鑫石油商务...', '亿创网安'],
#       dtype=object)

# %%
df.salary.unique()
# Out:
# array(['9-14K', '2-3K', '5-10K', '3-8K', '10-15K', '8-13K', '5-6K',
#        '10-15K·15薪', '8-10K·14薪', '7-9K', '10-15K·13薪', '5-9K', '5-8K',
#        '6-10K', '8-12K', '5-7K', '15-20K', '4-7K', '30-50K·14薪', '4-6K',
#        '3-7K', '10-15K·14薪', '7-8K', '4-5K', '11-18K', '12-17K·15薪',
#        '11-12K', '7-12K', '20-25K', '7-12K·13薪', '8-13K·13薪',
#        '15-25K·16薪', '4-9K', '8-10K', '4-8K', '3-6K', '12-20K', '10-11K',
#        '12-24K', '3-4K', '6-7K', '6-8K', '8-12K·13薪', '6-10K·13薪',
#        '8-11K', '12-15K·13薪', '3-5K·14薪', '6-11K', '8-15K', '10-11K·16薪',
#        '15-30K·16薪', '2-7K', '15-20K·13薪', '15-30K', '10-13K·13薪',
#        '18-35K', '12-16K·13薪', '3-5K', '12-18K·14薪', '11-22K', '14-20K',
#        '8-12K·15薪', '10-12K·15薪', '12-24K·13薪', '8-13K·15薪', '12-18K',
#        '15-25K', '20-30K·13薪', '7-10K', '11-20K·14薪', '18-35K·13薪',
#        '20-40K', '11-16K·13薪', '12-14K', '11-14K·13薪', '4-8K·13薪', '6-9K',
#        '25-35K·15薪', '15-28K·13薪', '11-20K', '8-12K·14薪', '20-30K·16薪',
#        '5-10K·13薪', '7-14K', '10-20K', '10-13K', '12-15K', '7-11K',
#        '6-9K·13薪', '12-17K', '4-6K·15薪', '15-20K·14薪', '11-13K·13薪',
#        '8-16K', '9-14K·13薪', '10-11K·14薪', '15-16K', '20-40K·18薪',
#        '9-13K·13薪', '11-18K·14薪', '8-13K·14薪', '15-25K·13薪', '22-40K',
#        '20-40K·15薪', '26-50K', '15-30K·14薪', '13-26K', '20-35K', '25-50K',
#        '11-18K·13薪', '20-35K·14薪', '8-10K·13薪', '9-10K', '4-6K·13薪',
#        '20-40K·14薪', '2-4K', '1-4K', '6-8K·13薪', '7-9K·14薪', '11-20K·13薪',
#        '7-10K·14薪', '5-8K·13薪', '4-7K·13薪', '7-11K·13薪', '14-25K·14薪',
#        '20-30K', '20-25K·19薪', '30-60K', '15-30K·13薪', '12-22K', '13-18K',
#        '15-28K', '17-28K·15薪', '13-25K', '17-34K', '30-45K', '15-25K·14薪',
#        '25-35K', '4-9K·14薪', '20-40K·16薪', '11-22K·14薪', '5-10K·14薪',
#        '12-20K·13薪', '18-28K', '30-50K·13薪', '14-25K', '18-25K·14薪',
#        '6-8K·14薪', '5-9K·13薪', '6-9K·14薪', '15-30K·15薪', '19-35K',
#        '7-10K·13薪', '13-20K·13薪', '40-70K', '9-14K·14薪', '9-13K',
#        '12-24K·14薪', '15-18K·13薪', '35-70K', '8-9K', '11-22K·13薪',
#        '30-40K', '17-30K', '11-17K', '18-35K·14薪', '4-6K·14薪', '7-8K·13薪',
#        '18-30K·14薪', '4-5K·14薪', '10-12K', '6-11K·14薪', '6-12K',
#        '4-5K·13薪', '7-12K·14薪', '1-5K', '18-19K', '13-20K', '5-8K·15薪',
#        '6-10K·14薪', '12-13K·15薪', '11-18K·15薪', '9-12K', '11-16K',
#        '15-22K·13薪', '18-30K·13薪', '13-25K·13薪', '25-40K', '5-10K·15薪',
#        '13-20K·15薪', '5-6K·13薪', '12-18K·13薪', '10-20K·18薪', '2-6K',
#        '12-20K·14薪', '15-22K', '15-16K·13薪', '30-60K·16薪', '30-50K·15薪',
#        '13-21K·13薪', '20-24K', '17-28K', '25-45K·15薪', '17-25K',
#        '25-50K·16薪', '20-21K·16薪', '17-25K·13薪', '15-25K·15薪',
#        '16-25K·14薪', '30-45K·16薪', '20-35K·15薪', '20-30K·15薪',
#        '20-27K·15薪', '50-80K·16薪', '22-27K', '28-50K·13薪', '18-30K',
#        '16-30K·14薪', '25-45K', '20-30K·14薪', '15-30K·17薪', '13-25K·14薪',
#        '18-27K', '20-40K·13薪', '18-36K', '20-35K·16薪', '25-35K·13薪',
#        '25-30K·15薪', '25-30K', '28-40K·14薪', '25-45K·16薪', '25-50K·14薪',
#        '15-25K·17薪', '25-40K·16薪', '35-40K', '10-15K·16薪', '6-10K·15薪',
#        '20-35K·13薪', '19-32K·16薪', '30-50K·16薪', '25-30K·14薪',
#        '7-11K·15薪', '40-70K·16薪', '25-40K·15薪', '30-55K·18薪',
#        '25-35K·14薪', '18-25K', '16-30K', '12-18K·15薪', '30-50K',
#        '30-50K·18薪', '30-35K·16薪', '25-45K·14薪', '12-20K·17薪',
#        '12-20K·15薪', '14-28K', '30-55K', '60-90K', '25-40K·13薪', '65-95K',
#        '25-50K·13薪', '16-30K·16薪', '24-38K', '45-60K', '26-35K',
#        '18-35K·16薪', '30-45K·15薪', '25-50K·15薪', '25-45K·13薪',
#        '30-55K·13薪', '50-80K·14薪', '40-55K·13薪', '19-30K·14薪', '22-30K',
#        '35-55K·14薪', '21-40K·15薪', '17-25K·15薪', '15-26K', '35-60K·14薪',
#        '18-35K·15薪', '30-40K·16薪', '30-60K·15薪', '30-55K·16薪',
#        '28-40K·16薪', '90-120K·14薪', '35-55K·16薪', '20-25K·15薪',
#        '20-40K·24薪', '40-50K·15薪', '25-35K·16薪', '25-40K·14薪',
#        '35-65K·16薪', '30-45K·14薪', '40-65K·14薪', '28-45K·14薪',
#        '30-60K·14薪', '22-40K·14薪', '28-45K·16薪', '18-25K·16薪',
#        '9-14K·16薪', '15-23K', '60-90K·16薪', '12-24K·16薪', '15-23K·13薪',
#        '12-20K·16薪', '13-18K·15薪', '11-20K·15薪', '9-12K·15薪',
#        '10-13K·14薪', '18-28K·16薪', '23-24K', '25-50K·18薪', '35-50K',
#        '18-28K·13薪', '15-17K', '8-11K·13薪', '15-18K', '12-17K·14薪',
#        '16-23K', '30-35K', '13-23K', '14-28K·13薪', '40-60K', '16-22K·13薪',
#        '14-20K·13薪', '15-26K·13薪', '30-35K·15薪', '18-30K·15薪',
#        '12-22K·22薪', '18-25K·15薪', '28-35K·13薪', '40-60K·14薪',
#        '18-25K·13薪', '20-21K·14薪', '12-23K·13薪', '40-70K·14薪',
#        '25-50K·17薪', '25-30K·13薪', '15-23K·14薪', '18-26K', '16-25K·13薪',
#        '7-10K·16薪', '12-18K·16薪', '13-18K·14薪', '15-20K·15薪', '7-9K·13薪',
#        '30-40K·14薪', '28-40K·15薪', '40-60K·15薪', '14-28K·14薪',
#        '15-30K·18薪', '16-25K', '12-16K·15薪', '30-55K·15薪', '12-20K·18薪',
#        '8-9K·13薪', '12-19K·13薪', '15-24K·15薪', '20-21K', '17-18K',
#        '50-80K', '13-26K·16薪', '16-30K·15薪', '11-22K·18薪', '30-60K·13薪',
#        '35-50K·15薪', '35-50K·16薪', '18-22K', '28-45K', '23-45K·16薪',
#        '13-16K', '16-21K·14薪', '11-16K·14薪', '6-11K·13薪', '6-7K·13薪',
#        '5-7K·13薪', '2-5K', '11-15K', '9-15K', '8-14K', '5-8K·14薪',
#        '3-5K·13薪', '6-8K·15薪', '6-9K·15薪', '6-11K·15薪'], dtype=object)

# %%
df['bottom']=df['salary'].str.extract('^(\d+).*')
df['top']=df['salary'].str.extract('^.*?-(\d+).*')
df['top'].fillna(df['bottom'],inplace=True)
df
# Out:
#      company      position address    salary  requires labels  \
# 0       安存科技         数据分析师      长沙     9-14K    1-3年本科  计算机软件
# 1       名利天下         数据分析师      长沙      2-3K  经验不限学历不限  移动互联网
# 2       长沙沃邦         数据分析师      长沙     5-10K    经验不限大专   企业服务
# 3         谊品         数据分析师      长沙      3-8K    3-5年大专  其他服务业
# 4       众美健康         数据分析师      长沙    10-15K    经验不限本科  计算机软件
# ...      ...           ...     ...       ...       ...    ...
# 2532    今日头条         数据分析师      西安  6-8K·15薪    1-3年本科  移动互联网
# 2533     众科源  7k起急招运营数据分析师      西安     7-10K    经验不限本科   电子商务
# 2534    今日头条         数据分析师      西安  6-8K·15薪    1-3年本科  移动互联网
# 2535    今日头条         数据分析师      西安  4-6K·15薪    经验不限本科  移动互联网
# 2536    今日头条         数据分析师      西安  4-6K·15薪    经验不限本科  移动互联网
#
#                                     tags bottom top
# 0                数据挖掘,大数据,工业数据,模型产品,特征工程      9  14
# 1              数据挖掘,数据分析师,店铺运营管理,战略目标,策划      2   3
# 2                  SPSS,VBA,建模,数据分析师,统计学      5  10
# 3               Python,SQL,数据分析师,数据分析管理,      3   8
# 4             大数据,数据挖掘,数据仓库,商业数据分析,数据分析师     10  15
# ...                                  ...    ...  ..
# 2532     Tableau，数据挖掘，BI，行业技术发展，心理学等相关专业      6   8
# 2533              数学，统计学，运营数据分析，亚马逊，电商平台      7  10
# 2534  Tableau，数据挖掘，行业技术发展，心理学等相关专业，数据分析师      6   8
# 2535         数据挖掘，Python，数据分析师，业务数据，风险报告      4   6
# 2536         数据挖掘，Python，数据开发，数据分析师，业务数据      4   6
#
# [2472 rows x 9 columns]

# %%
df['commision_pct']=df['salary'].str.extract('^.*?·(\d{2})薪')
df.commision_pct.fillna(12,inplace=True)
df.commision_pct=df.commision_pct.astype('float64')
df.commision_pct=df.commision_pct/12

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\hommet74\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\pandas\\__init__.py'>

# %%
df
# Out:
#      company      position address    salary  requires labels  \
# 0       安存科技         数据分析师      长沙     9-14K    1-3年本科  计算机软件
# 1       名利天下         数据分析师      长沙      2-3K  经验不限学历不限  移动互联网
# 2       长沙沃邦         数据分析师      长沙     5-10K    经验不限大专   企业服务
# 3         谊品         数据分析师      长沙      3-8K    3-5年大专  其他服务业
# 4       众美健康         数据分析师      长沙    10-15K    经验不限本科  计算机软件
# ...      ...           ...     ...       ...       ...    ...
# 2532    今日头条         数据分析师      西安  6-8K·15薪    1-3年本科  移动互联网
# 2533     众科源  7k起急招运营数据分析师      西安     7-10K    经验不限本科   电子商务
# 2534    今日头条         数据分析师      西安  6-8K·15薪    1-3年本科  移动互联网
# 2535    今日头条         数据分析师      西安  4-6K·15薪    经验不限本科  移动互联网
# 2536    今日头条         数据分析师      西安  4-6K·15薪    经验不限本科  移动互联网
#
#                                     tags bottom top  commision_pct
# 0                数据挖掘,大数据,工业数据,模型产品,特征工程      9  14           1.00
# 1              数据挖掘,数据分析师,店铺运营管理,战略目标,策划      2   3           1.00
# 2                  SPSS,VBA,建模,数据分析师,统计学      5  10           1.00
# 3               Python,SQL,数据分析师,数据分析管理,      3   8           1.00
# 4             大数据,数据挖掘,数据仓库,商业数据分析,数据分析师     10  15           1.00
# ...                                  ...    ...  ..            ...
# 2532     Tableau，数据挖掘，BI，行业技术发展，心理学等相关专业      6   8           1.25
# 2533              数学，统计学，运营数据分析，亚马逊，电商平台      7  10           1.00
# 2534  Tableau，数据挖掘，行业技术发展，心理学等相关专业，数据分析师      6   8           1.25
# 2535         数据挖掘，Python，数据分析师，业务数据，风险报告      4   6           1.25
# 2536         数据挖掘，Python，数据开发，数据分析师，业务数据      4   6           1.25
#
# [2472 rows x 10 columns]

# %%
df['bottom']=df.bottom.astype('int64')
df.top=df.top.astype('int64')
df['avg_salary']=(df.bottom+df.top)/2*df.commision_pct
df.avg_salary=df.avg_salary.astype('int64')
df
# Out:
#      company      position address    salary  requires labels  \
# 0       安存科技         数据分析师      长沙     9-14K    1-3年本科  计算机软件
# 1       名利天下         数据分析师      长沙      2-3K  经验不限学历不限  移动互联网
# 2       长沙沃邦         数据分析师      长沙     5-10K    经验不限大专   企业服务
# 3         谊品         数据分析师      长沙      3-8K    3-5年大专  其他服务业
# 4       众美健康         数据分析师      长沙    10-15K    经验不限本科  计算机软件
# ...      ...           ...     ...       ...       ...    ...
# 2532    今日头条         数据分析师      西安  6-8K·15薪    1-3年本科  移动互联网
# 2533     众科源  7k起急招运营数据分析师      西安     7-10K    经验不限本科   电子商务
# 2534    今日头条         数据分析师      西安  6-8K·15薪    1-3年本科  移动互联网
# 2535    今日头条         数据分析师      西安  4-6K·15薪    经验不限本科  移动互联网
# 2536    今日头条         数据分析师      西安  4-6K·15薪    经验不限本科  移动互联网
#
#                                     tags  bottom  top  commision_pct  \
# 0                数据挖掘,大数据,工业数据,模型产品,特征工程       9   14           1.00
# 1              数据挖掘,数据分析师,店铺运营管理,战略目标,策划       2    3           1.00
# 2                  SPSS,VBA,建模,数据分析师,统计学       5   10           1.00
# 3               Python,SQL,数据分析师,数据分析管理,       3    8           1.00
# 4             大数据,数据挖掘,数据仓库,商业数据分析,数据分析师      10   15           1.00
# ...                                  ...     ...  ...            ...
# 2532     Tableau，数据挖掘，BI，行业技术发展，心理学等相关专业       6    8           1.25
# 2533              数学，统计学，运营数据分析，亚马逊，电商平台       7   10           1.00
# 2534  Tableau，数据挖掘，行业技术发展，心理学等相关专业，数据分析师       6    8           1.25
# 2535         数据挖掘，Python，数据分析师，业务数据，风险报告       4    6           1.25
# 2536         数据挖掘，Python，数据开发，数据分析师，业务数据       4    6           1.25
#
#       avg_salary
# 0          11.50
# 1           2.50
# 2           7.50
# 3           5.50
# 4          12.50
# ...          ...
# 2532        8.75
# 2533        8.50
# 2534        8.75
# 2535        6.25
# 2536        6.25
#
# [2472 rows x 11 columns]

# %%
cols=list(df)
cols.insert(4,cols.pop(cols.index('bottom')))
cols.insert(5,cols.pop(cols.index('top')))
cols.insert(6,cols.pop(cols.index('commision_pct')))
cols.insert(7,cols.pop(cols.index('avg_salary')))
df=df.loc[:,cols]
df
# Out:
#      company      position address    salary  bottom  top  commision_pct  \
# 0       安存科技         数据分析师      长沙     9-14K       9   14           1.00
# 1       名利天下         数据分析师      长沙      2-3K       2    3           1.00
# 2       长沙沃邦         数据分析师      长沙     5-10K       5   10           1.00
# 3         谊品         数据分析师      长沙      3-8K       3    8           1.00
# 4       众美健康         数据分析师      长沙    10-15K      10   15           1.00
# ...      ...           ...     ...       ...     ...  ...            ...
# 2532    今日头条         数据分析师      西安  6-8K·15薪       6    8           1.25
# 2533     众科源  7k起急招运营数据分析师      西安     7-10K       7   10           1.00
# 2534    今日头条         数据分析师      西安  6-8K·15薪       6    8           1.25
# 2535    今日头条         数据分析师      西安  4-6K·15薪       4    6           1.25
# 2536    今日头条         数据分析师      西安  4-6K·15薪       4    6           1.25
#
#       avg_salary  requires labels                                tags
# 0          11.50    1-3年本科  计算机软件             数据挖掘,大数据,工业数据,模型产品,特征工程
# 1           2.50  经验不限学历不限  移动互联网           数据挖掘,数据分析师,店铺运营管理,战略目标,策划
# 2           7.50    经验不限大专   企业服务               SPSS,VBA,建模,数据分析师,统计学
# 3           5.50    3-5年大专  其他服务业            Python,SQL,数据分析师,数据分析管理,
# 4          12.50    经验不限本科  计算机软件          大数据,数据挖掘,数据仓库,商业数据分析,数据分析师
# ...          ...       ...    ...                                 ...
# 2532        8.75    1-3年本科  移动互联网     Tableau，数据挖掘，BI，行业技术发展，心理学等相关专业
# 2533        8.50    经验不限本科   电子商务              数学，统计学，运营数据分析，亚马逊，电商平台
# 2534        8.75    1-3年本科  移动互联网  Tableau，数据挖掘，行业技术发展，心理学等相关专业，数据分析师
# 2535        6.25    经验不限本科  移动互联网         数据挖掘，Python，数据分析师，业务数据，风险报告
# 2536        6.25    经验不限本科  移动互联网         数据挖掘，Python，数据开发，数据分析师，业务数据
#
# [2472 rows x 11 columns]

# %%
df.describe()
# Out:
#             bottom          top  commision_pct   avg_salary
# count  2472.000000  2472.000000    2472.000000  2472.000000
# mean     12.621764    21.355178       1.067894    18.700024
# std       8.410919    15.055249       0.111316    13.942462
# min       1.000000     3.000000       1.000000     2.500000
# 25%       6.000000     9.000000       1.000000     7.500000
# 50%      10.000000    15.000000       1.000000    13.541667
# 75%      18.000000    30.000000       1.083333    26.250000
# max      90.000000   120.000000       2.000000   122.500000

# %%
df=df[(df.avg_salary>3)&(df.avg_salary<70)]
df.describe()
# Out:
#             bottom          top  commision_pct   avg_salary
# count  2451.000000  2451.000000    2451.000000  2451.000000
# mean     12.460220    21.114239       1.067387    18.444087
# std       7.851397    14.400652       0.110750    13.185907
# min       2.000000     4.000000       1.000000     3.500000
# 25%       6.000000     9.000000       1.000000     7.500000
# 50%      10.000000    15.000000       1.000000    13.541667
# 75%      18.000000    30.000000       1.083333    26.250000
# max      50.000000    80.000000       2.000000    66.666667

# %%
df.requires.unique()
# Out:
# array(['1-3年本科', '经验不限大专', '3-5年大专', '经验不限本科', '3-5年本科', '1-3年硕士',
#        '1-3年大专', '1年以内大专', '5-10年本科', '1-3年学历不限', '1年以内本科', '在校/应届本科',
#        '5-10年大专', '3-5年硕士', '在校/应届大专', '1年以内学历不限', '经验不限学历不限', '1年以内硕士',
#        '1年以内高中', '5-10年硕士', '1-3年高中', '经验不限中专/中技', '经验不限硕士', '1-3年中专/中技',
#        '在校/应届硕士', '10年以上本科', '3-5年学历不限', '1-3年博士', '5-10年学历不限', '5-10年博士',
#        '经验不限博士', '经验不限高中', '10年以上硕士'], dtype=object)

# %%
df['experience']=df.requires.str.extract('^(\d+/?-\d+)')
df['diploma']=df.requires.str[-2:]
df
# Out:
#      company      position address    salary  bottom  top  commision_pct  \
# 0       安存科技         数据分析师      长沙     9-14K       9   14           1.00
# 2       长沙沃邦         数据分析师      长沙     5-10K       5   10           1.00
# 3         谊品         数据分析师      长沙      3-8K       3    8           1.00
# 4       众美健康         数据分析师      长沙    10-15K      10   15           1.00
# 5       百川创意       数据分析工程师      长沙     8-13K       8   13           1.00
# ...      ...           ...     ...       ...     ...  ...            ...
# 2532    今日头条         数据分析师      西安  6-8K·15薪       6    8           1.25
# 2533     众科源  7k起急招运营数据分析师      西安     7-10K       7   10           1.00
# 2534    今日头条         数据分析师      西安  6-8K·15薪       6    8           1.25
# 2535    今日头条         数据分析师      西安  4-6K·15薪       4    6           1.25
# 2536    今日头条         数据分析师      西安  4-6K·15薪       4    6           1.25
#
#       avg_salary requires labels                                tags  \
# 0          11.50   1-3年本科  计算机软件             数据挖掘,大数据,工业数据,模型产品,特征工程
# 2           7.50   经验不限大专   企业服务               SPSS,VBA,建模,数据分析师,统计学
# 3           5.50   3-5年大专  其他服务业            Python,SQL,数据分析师,数据分析管理,
# 4          12.50   经验不限本科  计算机软件          大数据,数据挖掘,数据仓库,商业数据分析,数据分析师
# 5          10.50   1-3年本科    互联网         分配策略,数据分析工程师,业务发展趋势,业务分析,渠道
# ...          ...      ...    ...                                 ...
# 2532        8.75   1-3年本科  移动互联网     Tableau，数据挖掘，BI，行业技术发展，心理学等相关专业
# 2533        8.50   经验不限本科   电子商务              数学，统计学，运营数据分析，亚马逊，电商平台
# 2534        8.75   1-3年本科  移动互联网  Tableau，数据挖掘，行业技术发展，心理学等相关专业，数据分析师
# 2535        6.25   经验不限本科  移动互联网         数据挖掘，Python，数据分析师，业务数据，风险报告
# 2536        6.25   经验不限本科  移动互联网         数据挖掘，Python，数据开发，数据分析师，业务数据
#
#      experience diploma
# 0           1-3      本科
# 2           NaN      大专
# 3           3-5      大专
# 4           NaN      本科
# 5           1-3      本科
# ...         ...     ...
# 2532        1-3      本科
# 2533        NaN      本科
# 2534        1-3      本科
# 2535        NaN      本科
# 2536        NaN      本科
#
# [2451 rows x 13 columns]

# %%
df.experience.unique()
# Out:
# array(['1-3', nan, '3-5', '5-10'], dtype=object)

# %%
df.experience.replace('1-3','1-3年',inplace=True)
df.experience.replace('3-5','3-5年',inplace=True)
df.experience.replace('5-10','5-10年',inplace=True)
df.experience.replace(np.nan,'经验不限',inplace=True)
df.experience.unique()
# Out:
# array(['1-3年', '经验不限', '3-5年', '5-10年'], dtype=object)

# %%
df.diploma.unique()
# Out:
# array(['本科', '大专', '硕士', '不限', '高中', '中技', '博士'], dtype=object)

# %%
pd.set_option('max_row',100)
df.labels.value_counts()
# Out:
# 互联网            680
# 移动互联网          301
# 计算机软件          238
# 电子商务           199
# 数据服务           144
# 游戏              65
# 在线教育            57
# 生活服务            53
# 医疗              51
# 贸易/进出口          43
# O2O             43
# 人力资源服务          42
# 企业服务            38
# 物流/仓储           31
# 批发/零售           30
# 其他行业            30
# 环保              22
# 计算机服务           21
# 信息安全            21
# 服装/纺织/皮革        20
# 银行              20
# 广告              20
# 咨询              19
# 智能硬件            19
# 通信/网络设备         17
# 工程施工            14
# 新零售             14
# 食品/饮料/烟酒        14
# 社交网络            13
# 证券/期货           13
# 电子/半导体/集成电路     11
# 其他服务业           11
# 制药              10
# 房地产             10
# 培训机构            10
# 其他专业服务           8
# 投资/融资            6
# 地产经纪             6
# 汽车生产             6
# 旅游               6
# 文化/体育/娱乐         5
# 机械设备/机电/重工       4
# 餐饮               4
# 新能源              4
# 仪器仪表/工业自动化       4
# 日化               4
# 学术/科研            3
# 媒体               3
# 检测/认证            3
# 家具/家电/家居         2
# 电力/热力/燃气/水利      2
# 分类信息             2
# 翻译               2
# 交通/运输            2
# 物业服务             2
# 建材               2
# 装修装饰             2
# 政府/公共事业          2
# 酒店               2
# 建筑设计             2
# 运营商              2
# 音乐/视频/阅读         1
# 印刷/包装/造纸         1
# 石油/石化            1
# 计算机硬件            1
# 化工               1
# 船舶/航空/航天         1
# 农/林/牧/渔          1
# 广播/影视            1
# 基金               1
# 法律               1
# 非盈利机构            1
# 4S店/后市场          1
# 租赁/拍卖/典当         1
# 保险               1
# 原材料及加工/模具        1
# 美容/美发            1
# 学前教育             1
# Name: labels, dtype: int64

# %%
df.loc[~df['labels'].isin(['互联网','计算机软件','移动互联网','电子商务','数据服务','信息安全','计算机服务','咨询','智能硬件','社交网络',
                           '互联网金融','游戏','在线教育','生活服务','O2O','医疗健康','贸易/进出口','物流/仓储 ','企业服务','银行','新零售']),'labels']='其他行业'
df.labels.value_counts()
# Out:
# 互联网       680
# 其他行业      463
# 移动互联网     301
# 计算机软件     238
# 电子商务      199
# 数据服务      144
# 游戏         65
# 在线教育       57
# 生活服务       53
# O2O        43
# 贸易/进出口     43
# 企业服务       38
# 信息安全       21
# 计算机服务      21
# 银行         20
# 智能硬件       19
# 咨询         19
# 新零售        14
# 社交网络       13
# Name: labels, dtype: int64

# %%
df.avg_salary.groupby(df.address).agg(['mean','median']).plot.bar(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='address'>

# %%
fig=plt.figure(figsize=(12,6),dpi=80)
plt.hist(df.avg_salary,bins=30,color='#f59355',alpha=0.5,edgecolor='white')
plt.ylabel('岗位数',fontsize=15)
plt.xlabel('薪资',fontsize=15)
plt.xticks(list(range(0,70,5)))
plt.show()

# %%
plt.figure(figsize=(16,16),dpi=80)
plt.subplot(121)
temp=df[df.avg_salary<10].groupby('address').avg_salary.count()
plt.pie(temp,labels=temp.index,autopct='%.2f%%')
plt.title('薪资小于10K各城市占比')
plt.subplot(122)
temp=df[df.avg_salary>10].groupby('address').avg_salary.count()
plt.pie(temp,labels=temp.index,autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1cfb53b9dc0>,
#   <matplotlib.patches.Wedge at 0x1cfb58d8e20>,
#   <matplotlib.patches.Wedge at 0x1cfb559b580>,
#   <matplotlib.patches.Wedge at 0x1cfb559bca0>,
#   <matplotlib.patches.Wedge at 0x1cfb5584430>,
#   <matplotlib.patches.Wedge at 0x1cfb5584b50>,
#   <matplotlib.patches.Wedge at 0x1cfb55752b0>,
#   <matplotlib.patches.Wedge at 0x1cfb58af6d0>,
#   <matplotlib.patches.Wedge at 0x1cfb5575e20>,
#   <matplotlib.patches.Wedge at 0x1cfb5571bb0>,
#   <matplotlib.patches.Wedge at 0x1cfb58af370>,
#   <matplotlib.patches.Wedge at 0x1cfb4e4b3d0>,
#   <matplotlib.patches.Wedge at 0x1cfb4e4baf0>,
#   <matplotlib.patches.Wedge at 0x1cfb4e41d60>,
#   <matplotlib.patches.Wedge at 0x1cfb4e41700>],
#  [Text(1.0171353519677202, 0.41885042172296105, '上海'),
#   Text(0.3312581817935941, 1.0489366124770372, '北京'),
#   Text(-0.44186498201010443, 1.0073506527883973, '南京'),
#   Text(-0.7842213103202947, 0.771360445213209, '厦门'),
#   Text(-0.909532985664501, 0.6186677201763631, '天津'),
#   Text(-1.071693311553522, 0.24793839148354055, '广州'),
#   Text(-1.0489366066617942, -0.33125820020769375, '成都'),
#   Text(-0.6242953870913676, -0.9056794519345349, '杭州'),
#   Text(-0.02046053521552018, -1.0998096955831471, '武汉'),
#   Text(0.5115051425606968, -0.9738390468316422, '深圳'),
#   Text(0.9030910695256107, -0.6280338527046841, '苏州'),
#   Text(1.001793748358487, -0.45432288710767443, '西安'),
#   Text(1.0509703921881914, -0.3247479557191996, '郑州'),
#   Text(1.0716932977704052, -0.24793845105992257, '重庆'),
#   Text(1.0945911885112152, -0.10895012635883336, '长沙')],
#  [Text(0.5548011010733018, 0.22846386639434235, '12.43%'),
#   Text(0.18068628097832407, 0.572147243169293, '15.39%'),
#   Text(-0.2410172629146024, 0.5494639924300349, '7.50%'),
#   Text(-0.4277570783565244, 0.4207420610253867, '4.61%'),
#   Text(-0.49610890127154594, 0.337455120096198, '1.12%'),
#   Text(-0.5845599881201029, 0.13523912262738574, '10.66%'),
#   Text(-0.5721472399973422, -0.18068629102237838, '6.32%'),
#   Text(-0.34052475659529136, -0.49400697378247355, '14.74%'),
#   Text(-0.011160291935738278, -0.5998961975908074, '3.88%'),
#   Text(0.2790028050331073, -0.5311849346354411, '12.11%'),
#   Text(0.4925951288321512, -0.34256391965710037, '3.16%'),
#   Text(0.5464329536500837, -0.2478124838769133, '2.63%'),
#   Text(0.5732565775571953, -0.17713524857410887, '1.38%'),
#   Text(0.5845599806020392, -0.1352391551235941, '0.92%'),
#   Text(0.5970497391879355, -0.05942734165027273, '3.16%')])

# %%
data1=df[df.address=='北京']['avg_salary']
data2=df[df.address=='上海']['avg_salary']
data3=df[df.address=='深圳']['avg_salary']
data4=df[df.address=='广州']['avg_salary']
data5=df[df.address=='杭州']['avg_salary']
plt.figure(figsize=(12,6),dpi=80)
plt.boxplot([data1,data2,data3,data4,data5],labels=['北京','上海','深圳','广州','杭州'],
           flierprops={'marker':'o','markerfacecolor':'r','color':'k'},
           patch_artist=True,boxprops={'color':'k','facecolor':'#FFFACF'})
ax=plt.gca()
ax.patch.set_facecolor('#FFFAFA')
ax.patch.set_alpha(0.6)
plt.title('主要城市薪资箱线图',fontsize=15)
plt.ylabel('薪资(单位：k)',fontsize=12)
plt.show()

# %%
d=df['avg_salary'].groupby(df.diploma)
